# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 
import seaborn as sns

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
COUNTRY = 'United States'
df_country = df[(df['job_country'] == COUNTRY)& (df['job_title_short'] == 'Data Analyst')].copy()
df_country = df_country.dropna(subset=['salary_year_avg'])
df_country
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# 180          Dos Palos, CA  via My ArkLaMiss Jobs         Full-time
# 410     Atlantic Beach, FL   via ComputerJobs.com         Full-time
# 988        Springfield, MA             via Indeed         Full-time
# 1413           Atlanta, GA        via Ai-Jobs.net         Full-time
# ...                    ...                    ...               ...
# 782637      Germantown, WI       via ZipRecruiter         Full-time
# 782798        New York, NY        via Ai-Jobs.net         Full-time
# 783588         Chicago, IL            via Ladders         Full-time
# 783866     Des Plaines, IL            via Ladders         Full-time
# 784882          Denton, TX           via LinkedIn         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 109                   True    Illinois, United States 2023-10-12 13:02:19
# 180                  False  California, United States 2023-02-27 13:00:39
# 410                  False                    Georgia 2023-01-10 13:59:02
# 988                  False    New York, United States 2023-11-21 13:00:13
# 1413                 False                    Georgia 2023-10-31 13:57:41
# ...                    ...                        ...                 ...
# 782637               False    Illinois, United States 2023-01-20 06:18:43
# 782798               False    New York, United States 2023-04-21 05:59:51
# 783588               False    Illinois, United States 2023-01-09 06:01:18
# 783866               False    Illinois, United States 2023-06-02 06:02:06
# 784882               False       Texas, United States 2023-01-04 15:29:24
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 109                     False                  True  United States
# 180                     False                  True  United States
# 410                     False                 False  United States
# 988                     False                 False  United States
# 1413                    False                  True  United States
# ...                       ...                   ...            ...
# 782637                   True                 False  United States
# 782798                   True                 False  United States
# 783588                  False                 False  United States
# 783866                  False                  True  United States
# 784882                  False                 False  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 109           year          89000.0              NaN
# 180           year          90250.0              NaN
# 410           year         133285.0              NaN
# 988           year          62623.0              NaN
# 1413          year          71300.0              NaN
# ...            ...              ...              ...
# 782637        year          70000.0              NaN
# 782798        year         111175.0              NaN
# 783588        year         125000.0              NaN
# 783866        year         115000.0              NaN
# 784882        year          87500.0              NaN
#
#                            company_name  \
# 109     Get It Recruit - Transportation
# 180        California Health & Wellness
# 410                                Citi
# 988          Springfield Public Schools
# 1413                         Guidehouse
# ...                                 ...
# 782637   Virtual Benefits Administrator
# 782798                              DRW
# 783588            United Air Lines, Inc
# 783866      Discover Financial Services
# 784882                   Insight Global
#
#                                                job_skills  \
# 109                         [python, r, alteryx, tableau]
# 180                                   [excel, powerpoint]
# 410     [sql, word, excel, visio, powerpoint, sharepoint]
# 988                                 [sql, excel, tableau]
# 1413                               [sql, excel, power bi]
# ...                                                   ...
# 782637                             [vba, sql, sql server]
# 782798                                         [terminal]
# 783588                    [sql, r, python, hadoop, excel]
# 783866                                             [unix]
# 784882                [sql, vba, tableau, excel, alteryx]
#
#                                           job_type_skills
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 180            {'analyst_tools': ['excel', 'powerpoint']}
# 410     {'analyst_tools': ['word', 'excel', 'visio', '...
# 988     {'analyst_tools': ['excel', 'tableau'], 'progr...
# 1413    {'analyst_tools': ['excel', 'power bi'], 'prog...
# ...                                                   ...
# 782637  {'databases': ['sql server'], 'programming': [...
# 782798                            {'other': ['terminal']}
# 783588  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 783866                                   {'os': ['unix']}
# 784882  {'analyst_tools': ['tableau', 'excel', 'altery...
#
# [4350 rows x 17 columns]

# %%
df_country_exploded = df_country.explode('job_skills')

# %%
df_da_skills = df_country_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_da_skills = df_da_skills.rename(columns={'count': 'skill_count', 'median':'median_salary'})
df_da_skills
# Out:
#             skill_count  median_salary
# job_skills
# sql                2508        91000.0
# excel              1808        84392.0
# python             1431        97500.0
# tableau            1364        92875.0
# sas                 926        90000.0
# ...                 ...            ...
# couchbase             1       160515.0
# chainer               1       100000.0
# chef                  1        85000.0
# cordova               1       113269.5
# node.js               1        83500.0
#
# [170 rows x 2 columns]

# %%
da_job_count = len(df_country)
df_da_skills['skill_percent'] = df_da_skills['skill_count']/da_job_count *100

skill_percent = 5

df_da_skills_high_demand = df_da_skills[df_da_skills['skill_percent'] > 5]
df_da_skills_high_demand
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                2508       91000.00      57.655172
# excel              1808       84392.00      41.563218
# python             1431       97500.00      32.896552
# tableau            1364       92875.00      31.356322
# sas                 926       90000.00      21.287356
# r                   893       92500.00      20.528736
# power bi            838       90000.00      19.264368
# powerpoint          462       85000.00      10.620690
# word                461       81194.75      10.597701
# sql server          286       92500.00       6.574713
# oracle              274       96923.75       6.298851
# go                  224       90000.00       5.149425

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['cognos',
#   'excel',
#   'tableau',
#   'splunk',
#   'sharepoint',
#   'ssrs',
#   'visio',
#   'sas',
#   'alteryx',
#   'ms access',
#   'dax',
#   'qlik',
#   'outlook',
#   'nuix',
#   'datarobot',
#   'sap',
#   'powerbi',
#   'spss',
#   'spreadsheet',
#   'ssis',
#   'esquisse',
#   'msaccess',
#   'power bi',
#   'powerpoint',
#   'sheets',
#   'word',
#   'looker',
#   'microstrategy'],
#  'programming': ['perl',
#   'typescript',
#   'fortran',
#   'c#',
#   'go',
#   'matlab',
#   'html',
#   'css',
#   'lua',
#   'shell',
#   'rust',
#   'groovy',
#   'solidity',
#   'sas',
#   'cobol',
#   'delphi',
#   'python',
#   'julia',
#   'visual basic',
#   'bash',
#   'vb.net',
#   'objective-c',
#   'mongodb',
#   'c++',
#   'mongo',
#   'swift',
#   'java',
#   'powershell',
#   'clojure',
#   'assembly',
#   'lisp',
#   'visualbasic',
#   'ruby',
#   'vba',
#   'crystal',
#   'dart',
#   'javascript',
#   'kotlin',
#   'php',
#   'ocaml',
#   'sass',
#   'scala',
#   'erlang',
#   'no-sql',
#   'r',
#   't-sql',
#   'nosql',
#   'sql',
#   'apl',
#   'c',
#   'golang',
#   'elixir',
#   'pascal',
#   'haskell',
#   'f#'],
#  'cloud': ['snowflake',
#   'firebase',
#   'databricks',
#   'oracle',
#   'digitalocean',
#   'ovh',
#   'openstack',
#   'linode',
#   'ibm cloud',
#   'bigquery',
#   'watson',
#   'redshift',
#   'colocation',
#   'aurora',
#   'heroku',
#   'azure',
#   'aws',
#   'gcp',
#   'vmware'],
#  'libraries': ['chainer',
#   'ionic',
#   'hugging face',
#   'spark',
#   'matplotlib',
#   'gtx',
#   'hadoop',
#   'pytorch',
#   'selenium',
#   'cordova',
#   'tidyr',
#   'nltk',
#   'rshiny',
#   'seaborn',
#   'flutter',
#   'numpy',
#   'tensorflow',
#   'mlr',
#   'dlib',
#   'opencv',
#   'pandas',
#   'xamarin',
#   'theano',
#   'graphql',
#   'ggplot2',
#   'scikit-learn',
#   'mxnet',
#   'spring',
#   'tidyverse',
#   'gdpr',
#   'capacitor',
#   'airflow',
#   'electron',
#   'mlpack',
#   'keras',
#   'kafka',
#   'qt',
#   'huggingface',
#   'plotly',
#   'shogun',
#   'react',
#   'jupyter',
#   'dplyr',
#   'pyspark'],
#  'other': ['github',
#   'svn',
#   'puppet',
#   'ansible',
#   'unreal',
#   'homebrew',
#   'flow',
#   'atlassian',
#   'yarn',
#   'codecommit',
#   'pulumi',
#   'bitbucket',
#   'docker',
#   'gitlab',
#   'jenkins',
#   'kubernetes',
#   'terminal',
#   'npm',
#   'chef',
#   'unity',
#   'git',
#   'terraform'],
#  'databases': ['cassandra',
#   'mysql',
#   'neo4j',
#   'dynamodb',
#   'elasticsearch',
#   'couchbase',
#   'couchdb',
#   'sql server',
#   'firebase',
#   'db2',
#   'sqlite',
#   'sqlserver',
#   'mariadb',
#   'redis',
#   'postgresql',
#   'mongodb',
#   'firestore'],
#  'os': ['redhat',
#   'macos',
#   'centos',
#   'debian',
#   'linux',
#   'fedora',
#   'wsl',
#   'suse',
#   'arch',
#   'ubuntu',
#   'kali',
#   'unix',
#   'windows'],
#  'async': ['microsoft lists',
#   'airtable',
#   'workfront',
#   'wimi',
#   'asana',
#   'planner',
#   'confluence',
#   'monday.com',
#   'clickup',
#   'wrike',
#   'notion',
#   'trello',
#   'jira',
#   'dingtalk',
#   'smartsheet'],
#  'webframeworks': ['ember.js',
#   'jquery',
#   'laravel',
#   'ruby on rails',
#   'drupal',
#   'phoenix',
#   'fastify',
#   'flask',
#   'express',
#   'asp.net core',
#   'angular.js',
#   'symfony',
#   'vue.js',
#   'next.js',
#   'node.js',
#   'gatsby',
#   'rubyon rails',
#   'fastapi',
#   'play framework',
#   'blazor',
#   'vue',
#   'deno',
#   'ruby',
#   'nuxt.js',
#   'node',
#   'svelte',
#   'angular',
#   'asp.netcore',
#   'django',
#   'react.js',
#   'asp.net'],
#  'sync': ['symphony',
#   'microsoft teams',
#   'zoom',
#   'webex',
#   'ringcentral',
#   'mattermost',
#   'wire',
#   'google chat',
#   'rocketchat',
#   'twilio',
#   'slack',
#   'unify']}

# %%
# turn dictionary into dataframe
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology       skills
# 0   analyst_tools       cognos
# 0   analyst_tools        excel
# 0   analyst_tools      tableau
# 0   analyst_tools       splunk
# 0   analyst_tools   sharepoint
# ..            ...          ...
# 9            sync  google chat
# 9            sync   rocketchat
# 9            sync       twilio
# 9            sync        slack
# 9            sync        unify
#
# [256 rows x 2 columns]

# %%
# merge df_DA_skills and df_technology
df_DA_skills_tech = df_da_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#      skill_count  median_salary  skill_percent     technology     skills
# 0           2508        91000.0      57.655172    programming        sql
# 1           1808        84392.0      41.563218  analyst_tools      excel
# 2           1431        97500.0      32.896552    programming     python
# 3           1364        92875.0      31.356322  analyst_tools    tableau
# 4            926        90000.0      21.287356  analyst_tools        sas
# ..           ...            ...            ...            ...        ...
# 169            1       160515.0       0.022989      databases  couchbase
# 170            1       100000.0       0.022989      libraries    chainer
# 171            1        85000.0       0.022989          other       chef
# 172            1       113269.5       0.022989      libraries    cordova
# 173            1        83500.0       0.022989  webframeworks    node.js
#
# [174 rows x 5 columns]

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_percent]

# %%
# !pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from adjustText) (2.4.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from adjustText) (3.10.8)
# Collecting scipy (from adjustText)
#   Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (26.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/data_analysis/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 10.5 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: scipy, adjustText
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [adjustText]
# Successfully installed adjustText-1.3.0 scipy-1.17.1

# %%
from adjustText import adjust_text
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_da_skills_high_demand.index):
    texts.append(plt.text(df_da_skills_high_demand['skill_percent'].iloc[i], df_da_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in the US')
plt.legend(title='Technology')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot 
plt.tight_layout()
plt.show()
